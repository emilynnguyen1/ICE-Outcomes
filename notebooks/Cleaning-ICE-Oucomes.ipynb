# %% [markdown]
# # ICE Outcomes: Data Exploration & Cleaning

# %% [markdown]
# ### Merging tables from 2012 - 2023 deportation data
# ---

# %%
# import modules
import pandas as pd

# %%
# 2012 detentions
detentions_12 = pd.read_excel("../data/ice_release_2011to2023/2023-ICFO_42034_Detentions_FY12_LESA-STU_FINAL-Redacted_raw.xlsx")
detentions_12.head()
# Out:
#             ERO-LESA Statistical Tracking Unit Unnamed: 1  Unnamed: 2  \
# 0  For Official Use Only (FOUO)/Pre-decisional        NaN         NaN
# 1                         FOIA 2023-ICFO-42034        NaN         NaN
# 2                                          NaN        NaN         NaN
# 3                        ICE Detentions FY2012        NaN         NaN
# 4                                 Detention ID    Case ID  Subject ID
#
#           Unnamed: 3              Unnamed: 4          Unnamed: 5  \
# 0                NaN                     NaN                 NaN
# 1                NaN                     NaN                 NaN
# 2                NaN                     NaN                 NaN
# 3                NaN                     NaN                 NaN
# 4  Stay Book In Date  Detention Book In Date  Detention Facility
#
#                 Unnamed: 6               Unnamed: 7                Unnamed: 8  \
# ...

# %% [markdown]
# ### Merging tables from 2023 - 2025 deportation data
# ---

# %%
# Read each Excel file - not sure if this works yet - it didnt run for me lol
arrests_2325 = pd.read_excel("../data/ice_release_2023to2025/ERO Admin Arrests_LESA-STU-FINAL Release.xlsx")
detainers_2325 = pd.read_excel("../data/ice_release_2023to2025/ERO Detainers_LESA-STU_FINAL Release.xlsx")
detentions_2325 = pd.read_excel("../data/ice_release_2023to2025/ICE Detentions_LESA-STU_FINAL Release.xlsx")

# Add source labels (optional but VERY useful for analysis later)
arrests_2325["source"] = "admin_arrests"
detainers_2325["source"] = "detainers"
detentions_2325["source"] = "detentions"

# Merge into one dataframe
ice_2023_2025_df = pd.concat(
    [arrests_2325, detainers_2325, detentions_2325],
    ignore_index=True
)

print(ice_2023_2025_df.shape)
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x10c3eb8c0>>
# Traceback (most recent call last):
#   File "/Users/emilynguyen/Library/Python/3.13/lib/python/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
