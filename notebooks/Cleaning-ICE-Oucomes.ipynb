# %% [markdown]
# # ICE Outcomes: Data Exploration & Cleaning

# %% [markdown]
# ### 2012 - 2023 deportation data
# ---

# %%
# import modules
import pandas as pd

# %%
# 2012 detentions
detentions_12 = pd.read_excel("../data/ice_release_2011to2023/2023-ICFO_42034_Detentions_FY12_LESA-STU_FINAL-Redacted_raw.xlsx", header=5)
detentions_12.head()
# Out:
#       Detention ID          Case ID       Subject ID Stay Book In Date  \
# 0  (b)(6)(b)(7)(c)  (b)(6)(b)(7)(c)  (b)(6)(b)(7)(c)        2012-08-09
# 1  (b)(6)(b)(7)(c)  (b)(6)(b)(7)(c)  (b)(6)(b)(7)(c)        2012-08-09
# 2  (b)(6)(b)(7)(c)  (b)(6)(b)(7)(c)  (b)(6)(b)(7)(c)        2012-08-28
# 3  (b)(6)(b)(7)(c)  (b)(6)(b)(7)(c)  (b)(6)(b)(7)(c)        2012-08-28
# 4  (b)(6)(b)(7)(c)  (b)(6)(b)(7)(c)  (b)(6)(b)(7)(c)        2012-04-26
#
#   Detention Book In Date            Detention Facility  \
# 0             2012-08-09      LAREDO PROCESSING CENTER
# 1             2012-09-15  T DON HUTTO DETENTION CENTER
# 2             2012-08-28           BALTIMORE HOLD ROOM
# 3             2012-08-28        HOWARD COUNTY DET CNTR
# 4             2012-04-26     FLORENCE STAGING FACILITY
#
#   Detention Facility Code Detention Book Out Date  \
# 0                 LRDICDF              2012-09-15
# 1                 CCAHUTX              2012-10-24
# ...

# %% [markdown]
# ### Tables from 2023 - 2025 deportation data
# ---

# %%
# arrests 2023 to 2025 df
arrests_23_25 = pd.read_excel("../data/ice_release_2023to2025/ERO Admin Arrests_LESA-STU-FINAL Release.xlsx", header=6)
arrests_23_25.head()
# Out:
#     Apprehension Date Apprehension State  Apprehension County  \
# 0 2023-09-23 09:01:00                NaN                  NaN
# 1 2023-11-09 11:06:00                NaN                  NaN
# 2 2025-09-11 11:58:34         CALIFORNIA                  NaN
# 3 2025-07-08 11:06:36                NaN                  NaN
# 4 2025-09-23 13:22:06              TEXAS                  NaN
#
#                        Apprehension AOR               Final Program  \
# 0        Atlanta Area of Responsibility  ERO Criminal Alien Program
# 1  San Francisco Area of Responsibility  ERO Criminal Alien Program
# 2  San Francisco Area of Responsibility  ERO Criminal Alien Program
# 3        El Paso Area of Responsibility                    Juvenile
# 4        El Paso Area of Responsibility  ERO Criminal Alien Program
#
#   Final Program Group        Apprehension Method Apprehension Criminality  \
# 0                 ICE    CAP Local Incarceration     1 Convicted Criminal
# ...

# %%
# arrests 2023 to 2025 information
arrests_23_25.columns
# Out:
# Index(['Apprehension Date', 'Apprehension State', 'Apprehension County',
#        'Apprehension AOR', 'Final Program', 'Final Program Group',
#        'Apprehension Method', 'Apprehension Criminality', 'Case Status',
#        'Case Category', 'Departed Date', 'Departure Country',
#        'Final Order Yes No', 'Final Order Date', 'Birth Date', 'Birth Year',
#        'Citizenship Country', 'Gender', 'Apprehension Site Landmark',
#        'Alien File Number', 'EID Case ID', 'EID Subject ID',
#        'Unique Identifier'],
#       dtype='str')

# %%
# detainers 2023 to 2025 df
detainers_23_25 = pd.read_excel("../data/ice_release_2023to2025/ERO Detainers_LESA-STU_FINAL Release.xlsx", header=6)
detainers_23_25.head()
# Out:
#   Detainer Prepare Date Facility State                          Facility AOR  \
# 0            2025-09-18       NEW YORK  New York City Area of Responsibility
# 1            2023-10-12     CALIFORNIA  San Francisco Area of Responsibility
# 2            2025-04-05     CALIFORNIA  San Francisco Area of Responsibility
# 3            2025-09-23          TEXAS                                   NaN
# 4            2024-12-16       ILLINOIS        Chicago Area of Responsibility
#
#       Port of Departure Departure Country Departed Date  \
# 0                   NaN               NaN           NaT
# 1  SAN ANTONIO, TX, POE          HONDURAS    2023-12-18
# 2      EL PASO, TX, POE          HONDURAS    2025-09-16
# 3                   NaN               NaN           NaT
# 4                   NaN               NaN           NaT
#
#                             Case Status Detainer Prepared Criminality  \
# 0                                ACTIVE    2 Pending Criminal Charges
# ...

# %%
detainers_23_25.columns
# Out:
# Index(['Detainer Prepare Date', 'Facility State', 'Facility AOR',
#        'Port of Departure', 'Departure Country', 'Departed Date',
#        'Case Status', 'Detainer Prepared Criminality', 'Detention Facility',
#        'Detention Facility Code', 'Facility City',
#        'Detainer Prep Threat Level', 'Gender', 'Citizenship Country',
#        'Birth Country', 'Birth Date', 'Birth Year', 'Entry Status',
#        'Most Serious Conviction (MSC) Charge', 'MSC Sentence Days',
#        'MSC Sentence Months', 'MSC Sentence Years', 'MSC Charge Code',
#        'MSC Charge Date', 'MSC Conviction Date', 'Felon',
#        'Processing Disposition', 'Case Category', 'Final Program',
#        'Time of Apprehension Case Category',
#        'Time of Apprehension Current Program', 'Apprehension Method',
#        'Case Final Order Yes No', 'Final Order Date', 'Apprehension Date',
#        'Entry Date', 'Prior Felony Yes No', 'Multiple Prior MISD Yes No',
# ...

# %%
# detentions 2023 to 2025 df
detentions_23_25 = pd.read_excel("../data/ice_release_2023to2025/ICE Detentions_LESA-STU_FINAL Release.xlsx", header=6)
detentions_23_25.head()
# Out:
#   Stay Book In Date Time   Book In Date Time  \
# 0    2023-05-10 07:50:00 2023-05-10 07:50:00
# 1    2024-05-25 03:55:00 2024-06-21 20:53:00
# 2    2024-05-25 03:55:00 2024-07-25 13:46:00
# 3    2024-02-07 16:30:00 2024-02-07 16:30:00
# 4    2024-02-07 16:30:00 2024-04-17 16:02:00
#
#                    Detention Facility Detention Facility Code  \
# 0  ELOY FED CTR FACILITY (CORE CIVIC)                     EAZ
# 1           MONTGOMERY PROCESSING CTR                 MTGPCTX
# 2         ALEXANDRIA STAGING FACILITY                 JENATLA
# 3  ELOY FED CTR FACILITY (CORE CIVIC)                     EAZ
# 4  JACKSON PARISH CORRECTIONAL CENTER                 JKPCCLA
#
#   Detention Book Out Date Time Stay Book Out Date Time  \
# 0          2023-09-22 09:40:00     2023-09-22 09:40:00
# 1          2024-07-25 13:41:00     2024-07-30 11:23:00
# 2          2024-07-30 11:23:00     2024-07-30 11:23:00
# 3          2024-04-17 01:59:00     2024-05-01 12:26:00
# ...

# %%
detentions_23_25.columns
# Out:
# Index(['Stay Book In Date Time', 'Book In Date Time', 'Detention Facility',
#        'Detention Facility Code', 'Detention Book Out Date Time',
#        'Stay Book Out Date Time', 'Detention Release Reason',
#        'Stay Book Out Date', 'Stay Release Reason', 'Religion', 'Gender',
#        'Marital Status', 'Birth Date', 'Birth Year', 'Ethnicity',
#        'Entry Status', 'Felon', 'Bond Posted Date', 'Bond Posted Amount',
#        'Case Status', 'Case Category', 'Final Order Yes No',
#        'Final Order Date', 'Case Threat Level', 'Book In Criminality',
#        'Final Charge', 'Departed Date', 'Departure Country',
#        'Initial Bond Set Amount', 'Citizenship Country', 'Final Program',
#        'Most Serious Conviction (MSC) Charge Code', 'MSC Charge',
#        'Alien File Number', 'EID Case ID', 'EID Subject ID',
#        'Unique Identifier'],
#       dtype='str')
